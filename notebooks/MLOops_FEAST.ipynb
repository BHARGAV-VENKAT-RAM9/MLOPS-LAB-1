# %%
# !pip -q install feast==0.64.0 pyarrow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 66.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 79.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import feast

print("Feast version:", feast.__version__)
# Out:
# Feast version: 0.64.0
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-f63401c4-66db-42b5-85d4-3fbff2af6027" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f63401c4-66db-42b5-85d4-3fbff2af6027">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv(
    "cse_curriculum_industry_skill_alignment_1500.csv"
)

print(df.head())
print("Dataset shape:", df.shape)
# Out:
#   student_id         university  gender  graduation_year         target_role  \
# 0    STU0001  Andhra University    Male             2027      Cloud Engineer
# 1    STU0002      KL University    Male             2025  Software Developer
# 2    STU0003      JNTU Kakinada  Female             2025     DevOps Engineer
# 3    STU0004   GITAM University    Male             2025  Software Developer
# 4    STU0005   GITAM University    Male             2025  Software Developer
#
#    cgpa  attendance_percent  internship_count  project_count  \
# 0  6.71                84.9                 0              1
# 1  8.08                76.6                 2              3
# 2  8.07                90.0                 2              4
# 3  7.87                82.8                 2              2
# 4  7.33                74.8                 3              2
#
#    certification_count  ...  communication_gap  \
# 0                  2.0  ...               11.0
# ...

# %%
print(df.columns.tolist())

df.info()

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# ['student_id', 'university', 'gender', 'graduation_year', 'target_role', 'cgpa', 'attendance_percent', 'internship_count', 'project_count', 'certification_count', 'hackathon_count', 'programming_language', 'curriculum_programming_score', 'industry_programming_required', 'programming_gap', 'curriculum_dsa_score', 'industry_dsa_required', 'dsa_gap', 'curriculum_dbms_score', 'industry_dbms_required', 'dbms_gap', 'curriculum_web_development_score', 'industry_web_development_required', 'web_development_gap', 'curriculum_cloud_score', 'industry_cloud_required', 'cloud_gap', 'curriculum_ai_ml_score', 'industry_ai_ml_required', 'ai_ml_gap', 'curriculum_cybersecurity_score', 'industry_cybersecurity_required', 'cybersecurity_gap', 'curriculum_devops_score', 'industry_devops_required', 'devops_gap', 'curriculum_communication_score', 'industry_communication_required', 'communication_gap', 'curriculum_problem_solving_score', 'industry_problem_solving_required', 'problem_solving_gap', 'overall_ski
# ...

# %%
# -----------------------------
# ENTITY
# -----------------------------

df["student_id"] = df["student_id"].astype(str)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
numeric_feast_columns = [
    "cgpa",
    "attendance_percent",
    "internship_count",
    "project_count",
    "certification_count",
    "hackathon_count",
    "curriculum_programming_score",
    "curriculum_dsa_score",
    "curriculum_dbms_score",
    "curriculum_web_development_score",
    "curriculum_cloud_score",
    "curriculum_ai_ml_score",
    "curriculum_cybersecurity_score",
    "curriculum_devops_score",
    "curriculum_communication_score",
    "curriculum_problem_solving_score",
    "overall_skill_alignment",
    "average_skill_gap",
    "employability_score"
]

for column in numeric_feast_columns:
    df[column] = pd.to_numeric(
        df[column],
        errors="coerce"
    )

    df[column] = df[column].fillna(
        df[column].median()
    )

# %%
df["target_role_encoded"] = (
    df["target_role"]
    .astype("category")
    .cat.codes
    .astype("int64")
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df["university_encoded"] = (
    df["university"]
    .astype("category")
    .cat.codes
    .astype("int64")
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df["programming_language_encoded"] = (
    df["programming_language"]
    .astype("category")
    .cat.codes
    .astype("int64")
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df["gender_encoded"] = (
    df["gender"]
    .astype("category")
    .cat.codes
    .astype("int64")
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df["total_experience"] = (
    df["internship_count"]
    + df["project_count"]
    + df["hackathon_count"]
).astype("int64")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
skill_columns = [
    "curriculum_programming_score",
    "curriculum_dsa_score",
    "curriculum_dbms_score",
    "curriculum_web_development_score",
    "curriculum_cloud_score",
    "curriculum_ai_ml_score",
    "curriculum_cybersecurity_score",
    "curriculum_devops_score",
    "curriculum_communication_score",
    "curriculum_problem_solving_score"
]

df["average_curriculum_skill"] = (
    df[skill_columns].mean(axis=1)
).astype("float32")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df["event_timestamp"] = pd.to_datetime(
    df["event_timestamp"],
    utc=True
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df["created_timestamp"] = (
    df["event_timestamp"]
    + pd.Timedelta(seconds=1)
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
feature_df = df[
    [
        "student_id",
        "event_timestamp",
        "created_timestamp",

        "cgpa",
        "attendance_percent",
        "internship_count",
        "project_count",
        "certification_count",
        "hackathon_count",

        "curriculum_programming_score",
        "curriculum_dsa_score",
        "curriculum_dbms_score",
        "curriculum_web_development_score",
        "curriculum_cloud_score",
        "curriculum_ai_ml_score",
        "curriculum_cybersecurity_score",
        "curriculum_devops_score",
        "curriculum_communication_score",
        "curriculum_problem_solving_score",

        "overall_skill_alignment",
        "average_skill_gap",
        "employability_score",

        "university_encoded",
        "gender_encoded",
        "target_role_encoded",
        "programming_language_encoded",

        "total_experience",
        "average_curriculum_skill"
    ]
].copy()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
label_df = df[
    [
        "student_id",
        "event_timestamp",
        "placement_status"
    ]
].copy()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
label_df["placed"] = (
    label_df["placement_status"]
    .map({
        "Not Placed": 0,
        "Placed": 1
    })
    .astype("int64")
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
label_df = label_df[
    [
        "student_id",
        "event_timestamp",
        "placed"
    ]
]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Feature data:")
display(feature_df.head())

print("Labels:")
display(label_df.head())
# Out:
# Feature data:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#   student_id           event_timestamp         created_timestamp  cgpa  \
# 0    STU0001 2026-05-20 00:00:00+00:00 2026-05-20 00:00:01+00:00  6.71
# 1    STU0002 2025-08-05 00:00:00+00:00 2025-08-05 00:00:01+00:00  8.08
# 2    STU0003 2026-01-28 00:00:00+00:00 2026-01-28 00:00:01+00:00  8.07
# 3    STU0004 2025-09-16 00:00:00+00:00 2025-09-16 00:00:01+00:00  7.87
# 4    STU0005 2025-07-17 00:00:00+00:00 2025-07-17 00:00:01+00:00  7.33
#
#    attendance_percent  internship_count  project_count  certification_count  \
# 0                84.9                 0              1                  2.0
# ...

# %%
import os

repo_path = "/content/cse_employability_feast"

os.makedirs(
    f"{repo_path}/data",
    exist_ok=True
)

print("Repository created:", repo_path)
# Out:
# Repository created: /content/cse_employability_feast

# %%
feature_df.to_parquet(
    f"{repo_path}/data/student_features.parquet",
    index=False
)

print("Feature parquet file created.")
# Out:
# Feature parquet file created.

# %%
feature_store_yaml = """
project: cse_employability_project

registry: data/registry.db

provider: local

offline_store:
  type: file

online_store:
  type: sqlite
  path: data/online_store.db
"""

with open(
    f"{repo_path}/feature_store.yaml",
    "w"
) as f:
    f.write(feature_store_yaml)

print("feature_store.yaml created.")
# Out:
# feature_store.yaml created.

# %%
feature_definition = '''
from datetime import timedelta

from feast import (
    Entity,
    FeatureView,
    FeatureService,
    Field,
    FileSource
)

from feast.types import (
    Float32,
    Int64
)


# -----------------------------
# ENTITY
# -----------------------------

student = Entity(
    name="student",
    join_keys=["student_id"],
    description="CSE student for employability skill analysis"
)


# -----------------------------
# DATA SOURCE
# -----------------------------

student_source = FileSource(
    name="student_source",
    path="data/student_features.parquet",
    timestamp_field="event_timestamp",
    created_timestamp_column="created_timestamp"
)


# -----------------------------
# FEATURE VIEW
# -----------------------------

student_feature_view = FeatureView(
    name="student_employability_features",

    entities=[student],

    ttl=timedelta(days=3650),

    schema=[
        Field(name="cgpa", dtype=Float32),
        Field(name="attendance_percent", dtype=Float32),

        Field(name="internship_count", dtype=Int64),
        Field(name="project_count", dtype=Int64),
        Field(name="certification_count", dtype=Int64),
        Field(name="hackathon_count", dtype=Int64),

        Field(
            name="curriculum_programming_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_dsa_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_dbms_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_web_development_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_cloud_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_ai_ml_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_cybersecurity_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_devops_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_communication_score",
            dtype=Float32
        ),

        Field(
            name="curriculum_problem_solving_score",
            dtype=Float32
        ),

        Field(
            name="overall_skill_alignment",
            dtype=Float32
        ),

        Field(
            name="average_skill_gap",
            dtype=Float32
        ),

        Field(
            name="employability_score",
            dtype=Float32
        ),

        Field(
            name="university_encoded",
            dtype=Int64
        ),

        Field(
            name="gender_encoded",
            dtype=Int64
        ),

        Field(
            name="target_role_encoded",
            dtype=Int64
        ),

        Field(
            name="programming_language_encoded",
            dtype=Int64
        ),

        Field(
            name="total_experience",
            dtype=Int64
        ),

        Field(
            name="average_curriculum_skill",
            dtype=Float32
        ),
    ],

    source=student_source,

    online=True
)


# -----------------------------
# FEATURE SERVICE
# -----------------------------

student_feature_service = FeatureService(
    name="cse_employability_service",

    features=[
        student_feature_view
    ]
)
'''

with open(
    f"{repo_path}/features.py",
    "w"
) as f:
    f.write(feature_definition)

print("features.py created successfully.")
# Out:
# features.py created successfully.

# %%
# !find /content/cse_employability_feast -maxdepth 2 -type f
# Out:
# /content/cse_employability_feast/feature_store.yaml
# /content/cse_employability_feast/data/student_features.parquet
# /content/cse_employability_feast/features.py

# %%
# %cd /content/cse_employability_feast
# Out:
# /content/cse_employability_feast

# %%
# !feast apply
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# ...

# %%
# !feast entities list
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# ...

# %%
# !feast feature-views list
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# ...

# %%
from feast import FeatureStore

store = FeatureStore(
    repo_path="/content/cse_employability_feast"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
feature_service = store.get_feature_service(
    "cse_employability_service"
)

print(feature_service)
# Out:
# {
#   "spec": {
#     "name": "cse_employability_service",
#     "features": [
#       {
#         "featureViewName": "student_employability_features",
#         "featureColumns": [
#           {
#             "name": "cgpa",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "attendance_percent",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "internship_count",
#             "valueType": "INT64"
#           },
#           {
#             "name": "project_count",
#             "valueType": "INT64"
#           },
#           {
#             "name": "certification_count",
#             "valueType": "INT64"
#           },
#           {
#             "name": "hackathon_count",
#             "valueType": "INT64"
#           },
#           {
#             "name": "curriculum_programming_score",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "curriculum_dsa_score",
# ...

# %%
entity_df = label_df[
    [
        "student_id",
        "event_timestamp",
        "placed"
    ]
].copy()

display(entity_df.head())
# Out:
#   student_id           event_timestamp  placed
# 0    STU0001 2026-05-20 00:00:00+00:00       0
# 1    STU0002 2025-08-05 00:00:00+00:00       1
# 2    STU0003 2026-01-28 00:00:00+00:00       1
# 3    STU0004 2025-09-16 00:00:00+00:00       1
# 4    STU0005 2025-07-17 00:00:00+00:00       1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
training_data = store.get_historical_features(
    entity_df=entity_df,
    features=feature_service
).to_df()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
display(training_data.head())
# Out:
#   student_id           event_timestamp  placed  cgpa  attendance_percent  \
# 0    STU0570 2025-01-01 00:00:00+00:00       1  6.49                86.4
# 1    STU0052 2025-01-02 00:00:00+00:00       1  9.55                79.6
# 2    STU1461 2025-01-02 00:00:00+00:00       1  8.33                91.3
# 3    STU1185 2025-01-02 00:00:00+00:00       1  6.81                84.1
# 4    STU0902 2025-01-02 00:00:00+00:00       1  7.00                94.7
#
#    internship_count  project_count  certification_count  hackathon_count  \
# 0                 1              3                  2.0                0
# 1                 2              1                  3.0                1
# 2                 3              2                  0.0                0
# 3                 0              3                  2.0                1
# 4                 1              5                  2.0                0
#
#    curriculum_programming_score  ...  curriculum_problem_solving_score  \
# ...

# %%
print(
    "Historical training data shape:",
    training_data.shape
)
# Out:
# Historical training data shape: (1500, 28)

# %%
feature_columns = [
    "cgpa",
    "attendance_percent",
    "internship_count",
    "project_count",
    "certification_count",
    "hackathon_count",

    "curriculum_programming_score",
    "curriculum_dsa_score",
    "curriculum_dbms_score",
    "curriculum_web_development_score",
    "curriculum_cloud_score",
    "curriculum_ai_ml_score",
    "curriculum_cybersecurity_score",
    "curriculum_devops_score",
    "curriculum_communication_score",
    "curriculum_problem_solving_score",

    "overall_skill_alignment",
    "average_skill_gap",
    "employability_score",

    "university_encoded",
    "gender_encoded",
    "target_role_encoded",
    "programming_language_encoded",

    "total_experience",
    "average_curriculum_skill"
]

# %%
X = training_data[
    feature_columns
]

y = training_data[
    "placed"
]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (1500, 25)
# y shape: (1500,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(
    max_depth=4,
    random_state=42
)

model.fit(
    X_train,
    y_train
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
predictions = model.predict(
    X_test
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(
    y_test,
    predictions
)

print(
    "Accuracy:",
    round(accuracy * 100, 2),
    "%"
)
# Out:
# Accuracy: 81.67 %
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print(
    feature_df["event_timestamp"].min()
)

print(
    feature_df["event_timestamp"].max()
)
# Out:
# 2025-01-01 00:00:00+00:00
# 2026-08-03 00:00:00+00:00

# %%
start_time = feature_df["event_timestamp"].min()
end_time = feature_df["event_timestamp"].max()

print("Start:", start_time)
print("End:", end_time)
# Out:
# Start: 2025-01-01 00:00:00+00:00
# End: 2026-08-03 00:00:00+00:00

# %%
start_str = start_time.strftime(
    "%Y-%m-%dT%H:%M:%S"
)

end_str = end_time.strftime(
    "%Y-%m-%dT%H:%M:%S"
)

print(start_str)
print(end_str)
# Out:
# 2025-01-01T00:00:00
# 2026-08-03T00:00:00

# %%
# !feast materialize {start_str} {end_str}
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# ...

# %%
online_features = store.get_online_features(
    features=feature_service,
    entity_rows=[
        {
            "student_id": "STU0025"
        }
    ]
).to_dict()

# %%
print(online_features)
# Out:
# {'student_id': ['STU0025'], 'curriculum_problem_solving_score': [79.69999694824219], 'attendance_percent': [95.5], 'total_experience': [8], 'programming_language_encoded': [4], 'project_count': [5], 'certification_count': [0], 'curriculum_dsa_score': [94.69999694824219], 'curriculum_communication_score': [62.79999923706055], 'employability_score': [95.13999938964844], 'average_skill_gap': [1.159999966621399], 'curriculum_devops_score': [78.19999694824219], 'curriculum_dbms_score': [92.69999694824219], 'curriculum_cloud_score': [92.5], 'internship_count': [3], 'hackathon_count': [0], 'target_role_encoded': [4], 'cgpa': [7.150000095367432], 'curriculum_web_development_score': [94.69999694824219], 'gender_encoded': [1], 'curriculum_cybersecurity_score': [79.5], 'overall_skill_alignment': [98.83999633789062], 'curriculum_ai_ml_score': [92.0], 'university_encoded': [5], 'average_curriculum_skill': [85.52999877929688], 'curriculum_programming_score': [88.5]}

# %%
online_df = pd.DataFrame(
    online_features
)

display(online_df)
# Out:
#   student_id  curriculum_problem_solving_score  attendance_percent  \
# 0    STU0025                         79.699997                95.5
#
#    total_experience  programming_language_encoded  project_count  \
# 0                 8                             4              5
#
#    certification_count  curriculum_dsa_score  curriculum_communication_score  \
# 0                    0             94.699997                       62.799999
#
#    employability_score  ...  target_role_encoded  cgpa  \
# 0            95.139999  ...                    4  7.15
#
#    curriculum_web_development_score  gender_encoded  \
# 0                         94.699997               1
#
#    curriculum_cybersecurity_score  overall_skill_alignment  \
# 0                            79.5                98.839996
#
#    curriculum_ai_ml_score  university_encoded  average_curriculum_skill  \
# 0                    92.0                   5                 85.529999
#
#    curriculum_programming_score
# ...

# %%
final_model = DecisionTreeClassifier(
    max_depth=4,
    random_state=42
)

final_model.fit(
    X,
    y
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
X_online = online_df[
    feature_columns
]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
prediction = final_model.predict(
    X_online
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
if prediction[0] == 1:
    print("Predicted placement status: Placed")
else:
    print("Predicted placement status: Not Placed")
# Out:
# Predicted placement status: Placed

# %%
online_features = store.get_online_features(
    features=feature_service,
    entity_rows=[
        {"student_id": "STU0010"},
        {"student_id": "STU0020"},
        {"student_id": "STU0030"},
        {"student_id": "STU0040"}
    ]
).to_dict()

# %%
online_df = pd.DataFrame(
    online_features
)

display(online_df)
# Out:
#   student_id  curriculum_problem_solving_score  attendance_percent  \
# 0    STU0010                         80.699997           83.500000
# 1    STU0020                         81.500000           81.900002
# 2    STU0030                         75.699997           81.699997
# 3    STU0040                         80.199997           83.699997
#
#    total_experience  programming_language_encoded  project_count  \
# 0                 3                             0              3
# 1                 5                             3              3
# 2                 2                             3              1
# 3                 4                             2              2
#
#    certification_count  curriculum_dsa_score  curriculum_communication_score  \
# 0                    1             79.400002                       82.900002
# 1                    4             82.099998                       71.000000
# ...

# %%
online_df["predicted_placement"] = (
    final_model.predict(
        online_df[feature_columns]
    )
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
online_df["predicted_placement_status"] = (
    online_df["predicted_placement"]
    .map({
        0: "Not Placed",
        1: "Placed"
    })
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
display(
    online_df[
        [
            "student_id",
            "predicted_placement_status"
        ]
    ]
)
# Out:
#   student_id predicted_placement_status
# 0    STU0010                     Placed
# 1    STU0020                     Placed
# 2    STU0030                     Placed
# 3    STU0040                     Placed
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
